# %% [markdown]
# # Histograms

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns ; sns.set() # ; means seperate line of code

# %% [markdown]
# <hr>
# <br>
# <br>

# %% [markdown]
# ## How has the NBA changed since 1950?

# %% [markdown]
# #### Load Seasons Data

# %%
nba = pd.read_csv("../data/nba_1950/season_stats.csv")

# %% [markdown]
# #### But first, Quick Exploration of the dataset.

# %% [markdown]
# [Data Dictionary](https://www.basketball-reference.com/about/glossary.html)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24691 entries, 0 to 24690
# Data columns (total 52 columns):
# Year      24624 non-null float64
# Player    24624 non-null object
# Pos       24624 non-null object
# Age       24616 non-null float64
# Tm        24624 non-null object
# G         24624 non-null float64
# GS        18233 non-null float64
# MP        24138 non-null float64
# PER       24101 non-null float64
# TS%       24538 non-null float64
# 3PAr      18839 non-null float64
# FTr       24525 non-null float64
# ORB%      20792 non-null float64
# DRB%      20792 non-null float64
# TRB%      21571 non-null float64
# AST%      22555 non-null float64
# STL%      20792 non-null float64
# BLK%      20792 non-null float64
# TOV%      19582 non-null float64
# USG%      19640 non-null float64
# blanl     0 non-null float64
# OWS       24585 non-null float64
# DWS       24585 non-null float64
# WS        24585 non-null float64
# WS/48     24101 non-null float64
# blank2    0 non-null float64
# OBPM      20797 non-null float64
# DBPM      20797 non-null float64
# BPM       20797 non-null float64
# VORP      20797 non-null float64
# FG        24624 non-null float64
# FGA       24624 non-null float64
# FG%       24525 non-null float64
# 3P        18927 non-null float64
# 3PA       18927 non-null float64
# 3P%       15416 non-null float64
# 2P        24624 non-null float64
# 2PA       24624 non-null float64
# 2P%       24496 non-null float64
# eFG%      24525 non-null float64
# FT        24624 non-null float64
# FTA       24624 non-null float64
# FT%       23766 non-null float64
# ORB       20797 non-null float64
# DRB       20797 non-null float64
# TRB       24312 non-null float64
# AST       24624 non-null float64
# STL       20797 non-null float64
# BLK       20797 non-null float64
# TOV       19645 non-null float64
# PF        24624 non-null float64
# PTS       24624 non-null float64
# dtypes: float64(49), object(3)
# memory usage: 9.8+ MB

# %% [markdown]
# #### Lets look at a few of the rows.

# %%
nba.head(10)
# Out:
#      Year           Player  Pos   Age   Tm     G  GS  MP  PER    TS%  ...  \
# 0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN  0.368  ...
# 1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN  0.435  ...
# 2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN  0.394  ...
# 3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN  0.312  ...
# 4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN  0.308  ...
# 5  1950.0       Ed Bartels    F  24.0  NYK   2.0 NaN NaN  NaN  0.376  ...
# 6  1950.0      Ralph Beard    G  22.0  INO  60.0 NaN NaN  NaN  0.422  ...
# 7  1950.0       Gene Berce  G-F  23.0  TRI   3.0 NaN NaN  NaN  0.275  ...
# 8  1950.0    Charlie Black  F-C  28.0  TOT  65.0 NaN NaN  NaN  0.346  ...
# 9  1950.0    Charlie Black  F-C  28.0  FTW  36.0 NaN NaN  NaN  0.362  ...
#
#      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
# 5  0.667  NaN  NaN  NaN    0.0  NaN  NaN  NaN    2.0    4.0
# 6  0.762  NaN  NaN  NaN  233.0  NaN  NaN  NaN  132.0  895.0
# 7  0.000  NaN  NaN  NaN    2.0  NaN  NaN  NaN    6.0   10.0
# 8  0.651  NaN  NaN  NaN  163.0  NaN  NaN  NaN  273.0  661.0
# 9  0.632  NaN  NaN  NaN   75.0  NaN  NaN  NaN  140.0  382.0
#
# [10 rows x 52 columns]

# %% [markdown]
# #### What are some things that you notice right off the bat?

# %%
nba.tail(10)
# Out:
#          Year             Player Pos   Age   Tm     G    GS      MP   PER  \
# 24681  2017.0       Delon Wright  PG  24.0  TOR  27.0   0.0   446.0  15.0
# 24682  2017.0        James Young  SG  21.0  BOS  29.0   0.0   220.0  10.0
# 24683  2017.0          Joe Young  PG  24.0  IND  33.0   0.0   135.0  11.4
# 24684  2017.0         Nick Young  SG  31.0  LAL  60.0  60.0  1556.0  14.1
# 24685  2017.0     Thaddeus Young  PF  28.0  IND  74.0  74.0  2237.0  14.9
# 24686  2017.0        Cody Zeller  PF  24.0  CHO  62.0  58.0  1725.0  16.7
# 24687  2017.0       Tyler Zeller   C  27.0  BOS  51.0   5.0   525.0  13.0
# 24688  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0   0.0   108.0   7.3
# 24689  2017.0        Paul Zipser  SF  22.0  CHI  44.0  18.0   843.0   6.9
# 24690  2017.0        Ivica Zubac   C  19.0  LAL  38.0  11.0   609.0  17.0
#
#          TS%  ...    FT%    ORB    DRB    TRB    AST    STL   BLK   TOV  \
# 24681  0.535  ...  0.764   16.0   32.0   48.0   57.0   27.0  11.0  25.0
# 24682  0.549  ...  0.667    6.0   20.0   26.0    4.0   10.0   2.0   4.0
# 24683  0.433  ...  0.733    1.0   16.0   17.0   15.0    4.0   0.0   5.0
# 24684  0.588  ...  0.856   25.0  112.0  137.0   58.0   37.0  14.0  36.0
# 24685  0.562  ...  0.523  131.0  318.0  449.0  122.0  114.0  30.0  96.0
# 24686  0.604  ...  0.679  135.0  270.0  405.0   99.0   62.0  58.0  65.0
# 24687  0.508  ...  0.564   43.0   81.0  124.0   42.0    7.0  21.0  20.0
# 24688  0.346  ...  0.600   11.0   24.0   35.0    4.0    2.0   5.0   3.0
# 24689  0.503  ...  0.775   15.0  110.0  125.0   36.0   15.0  16.0  40.0
# 24690  0.547  ...  0.653   41.0  118.0  159.0   30.0   14.0  33.0  30.0
#
#           PF    PTS
# 24681   31.0  150.0
# 24682   15.0   68.0
# 24683    5.0   68.0
# 24684  137.0  791.0
# 24685  135.0  814.0
# 24686  189.0  639.0
# 24687   61.0  178.0
# 24688   17.0   23.0
# 24689   78.0  240.0
# 24690   66.0  284.0
#
# [10 rows x 52 columns]

# %% [markdown]
# <br>

# %%
nba[nba["Player"] == "Michael Jordan"]
# Out:
# Empty DataFrame
# Columns: [Year, Player, Pos, Age, Tm, G, GS, MP, PER, TS%, 3PAr, FTr, ORB%, DRB%, TRB%, AST%, STL%, BLK%, TOV%, USG%, blanl, OWS, DWS, WS, WS/48, blank2, OBPM, DBPM, BPM, VORP, FG, FGA, FG%, 3P, 3PA, 3P%, 2P, 2PA, 2P%, eFG%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS]
# Index: []
#
# [0 rows x 52 columns]

# %% [markdown]
# ### Shooting Percentage

# %% [markdown]
# #### Use pandas `.value_counts()` to look at the distribution of `TS%`.

# %%
shoot_percentage = nba['TS%'].value_counts()
shoot_percentage.head()
# Out:
# 0.500    235
# 0.000    201
# 0.521    188
# 0.533    186
# 0.530    182
# Name: TS%, dtype: int64

# %% [markdown]
# #### Use pandas `.hist()` method to visualize distribution of `TS%`

# %%
nba['TS%'].hist(bins=20)

# # Make it pretty
# ax = plt.gca()
# ax.set_title("True Shooting % Across all NBA Seasons")
# ax.set_xlabel("True Shooting Percentage")
# ax.set_ylabel("# of Players")

# # "print" the plot
# plt.show()

# %%
nba['TS%'].hist(bins=20)

# Make it pretty
ax = plt.gca() # Get the current Axes instance on the current figure
ax.set_title("True Shooting % Across all NBA Seasons")
ax.set_xlabel("True Shooting Percentage")
ax.set_ylabel("# of Players")

# "print" the plot
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# ### Prep work for Answering Question.

# %%
first_year = nba['Year'].min()
last_year = nba['Year'].max()
print(first_year)
print(last_year)
# Out:
# 1950.0
# 2017.0

# %%
nba_1950 = nba[nba['Year'] == first_year]
nba_2017 = nba[nba['Year'] == last_year]

# %% [markdown]
# <br>

# %% [markdown]
# ### Shooting Percentage in 1950

# %%
nba_1950['TS%'].hist(bins=20)

# Make it pretty
ax = plt.gca()
ax.set_title("True Shooting in 1950")
ax.set_xlabel("True Shooting Percentage")
ax.set_ylabel("# of Players")

# "print" the plot
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# ### Shooting Percentage in 2017

# %%
nba_2017['TS%'].hist(bins=20)

# Make it pretty
ax = plt.gca()
ax.set_title("True Shooting % in 2017")
ax.set_xlabel("True Shooting Percentage")
ax.set_ylabel("# of Players")

# "print" the plot
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# #### Using only the data from the Histograms for both years... What has happened to the True Shooting Percentage between 1950 and 2017?

# %%
print(nba_2017['TS%'].mean())
print(nba_2017['TS%'].median())
print(nba_2017['TS%'].var())
print(nba_1950['TS%'].mean())
print(nba_1950['TS%'].median())
print(nba_1950['TS%'].var())

print(nba_2017['TS%'].mean() - nba_1950['TS%'].mean() )
print(nba_2017['TS%'].mean() / nba_1950['TS%'].mean() ) # .37 percent better
# Out:
# 0.5267993254637435
# 0.537
# 0.008770248513057745
# 0.38403205128205126
# 0.385
# 0.006616976461373565
# 0.14276727418169227
# 1.371758746971974

# %% [markdown]
# # short answer
# We can see that the True Shooting Percentage has shifted over the different years.
# The avg True Shooting Percentage has increased by 14 percent

# %%
nba_1950['TS%'].value_counts().sort_index(ascending=False)
# Out:
# 1.000    1
# 0.608    1
# 0.592    1
# 0.579    1
# 0.548    1
# 0.515    1
# 0.513    1
# 0.507    1
# 0.506    1
# 0.503    1
# 0.502    1
# 0.500    1
# 0.498    1
# 0.497    1
# 0.496    1
# 0.493    1
# 0.492    1
# 0.491    1
# 0.487    2
# 0.486    1
# 0.485    1
# 0.484    1
# 0.480    1
# 0.479    2
# 0.472    2
# 0.471    3
# 0.470    1
# 0.467    1
# 0.466    2
# 0.464    1
#         ..
# 0.303    2
# 0.302    3
# 0.295    1
# 0.294    1
# 0.293    1
# 0.292    1
# 0.291    1
# 0.290    2
# 0.289    1
# 0.281    2
# 0.278    1
# 0.277    1
# 0.275    1
# 0.268    1
# 0.266    1
# 0.262    1
# 0.257    1
# 0.242    1
# 0.230    1
# 0.218    1
# 0.198    1
# 0.196    1
# 0.190    1
# 0.184    1
# 0.183    1
# 0.182    1
# 0.170    1
# 0.131    1
# 0.121    1
# 0.000    1
# Name: TS%, Length: 177, dtype: int64

# %%
nba_2017['TS%'].value_counts().sort_index(ascending=False).head(10)
# Out:
# 0.820    1
# 0.799    1
# 0.798    2
# 0.773    1
# 0.753    1
# 0.703    1
# 0.688    1
# 0.682    2
# 0.677    1
# 0.676    1
# Name: TS%, dtype: int64

# %%
top_tsp_index = nba_1950[nba_1950['TS%'] == 1.00].index.values[0]
nba_1950.iloc[top_tsp_index, :]

nba_1950[nba_1950['TS%'] == 1.00]["Player"]

nba_1950.iloc[nba_1950['TS%'].idxmax()]
nba_1950['TS%'].idxmax()

nba["Player"].iloc[nba_1950["TS%"].idxmax()]

# top_tsp_index = nba_1950['TS%'].sort_values(ascending=False).index[0]
# nba_1950.iloc[top_tsp_index, :]['Player']
# Out:
# 'Normie Glick'

# %% [markdown]
# <hr>
# <br>
# <br>

# %% [markdown]
# ## Does The College that a player attended affect performance in NBA?

# %% [markdown]
# #### Load Player Data

# %%
players = pd.read_csv('../data/nba_1950/player_data.csv')
players
# Out:
#                      name  year_start  year_end position height  weight  \
# 0          Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1         Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2     Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3      Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4       Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
# 5     Shareef Abdur-Rahim        1997      2008        F    6-9   225.0
# 6           Tom Abernethy        1977      1981        F    6-7   220.0
# 7             Forest Able        1957      1957        G    6-3   180.0
# 8          John Abramovic        1947      1948        F    6-3   195.0
# 9            Alex Abrines        2017      2018      G-F    6-6   190.0
# 10             Alex Acker        2006      2009        G    6-5   185.0
# 11           Don Ackerman        1954      1954        G    6-0   183.0
# 12             Mark Acres        1988      1993      F-C   6-11   220.0
# 13              Bud Acton        1968      1968        F    6-6   210.0
# 14             Quincy Acy        2013      2018        F    6-7   240.0
# 15            Alvan Adams        1976      1988      C-F    6-9   210.0
# 16              Don Adams        1971      1977        F    6-6   210.0
# 17           George Adams        1973      1975      F-G    6-5   210.0
# 18           Hassan Adams        2007      2009        G    6-4   220.0
# 19           Jordan Adams        2015      2016        G    6-5   209.0
# 20          Michael Adams        1986      1996        G   5-10   162.0
# 21           Steven Adams        2014      2018        C    7-0   255.0
# 22         Rafael Addison        1987      1997      F-G    6-7   215.0
# 23            Bam Adebayo        2018      2018      C-F   6-10   243.0
# 24           Rick Adelman        1969      1975        G    6-1   175.0
# 25            Jeff Adrien        2011      2015        F    6-7   245.0
# 26          Arron Afflalo        2008      2018        G    6-5   210.0
# 27           Maurice Ager        2007      2011        G    6-5   202.0
# 28           Mark Aguirre        1982      1994      F-G    6-6   232.0
# 29           Blake Ahearn        2008      2012        G    6-2   190.0
# ...                   ...         ...       ...      ...    ...     ...
# 4520          James Young        2015      2017      G-F    6-6   215.0
# 4521            Joe Young        2016      2018        G    6-2   180.0
# 4522       Korleone Young        1999      1999        F    6-7   213.0
# 4523        Michael Young        1985      1990      F-G    6-7   220.0
# 4524           Nick Young        2008      2018      G-F    6-7   210.0
# 4525          Perry Young        1987      1987        G    6-5   210.0
# 4526            Sam Young        2010      2013        F    6-6   220.0
# 4527       Thaddeus Young        2008      2018        F    6-8   221.0
# 4528            Tim Young        2000      2000        C    7-0   220.0
# 4529              Sun Yue        2009      2009        G    6-9   205.0
# 4530        Max Zaslofsky        1947      1956      G-F    6-2   170.0
# 4531         Zeke Zawoluk        1953      1955      F-C    6-7   215.0
# 4532          Cody Zeller        2014      2018      C-F    7-0   240.0
# 4533          Dave Zeller        1962      1962        G    6-1   175.0
# 4534          Gary Zeller        1971      1972        G    6-3   205.0
# 4535         Harry Zeller        1947      1947      C-F    6-4   210.0
# 4536          Luke Zeller        2013      2013        C   6-11   245.0
# 4537         Tyler Zeller        2013      2018      F-C    7-0   253.0
# 4538            Tony Zeno        1980      1980        F    6-8   210.0
# 4539     Phil Zevenbergen        1988      1988        C   6-10   230.0
# 4540          Wang Zhizhi        2001      2005        C    7-0   255.0
# 4541         George Zidek        1996      1998        C    7-0   250.0
# 4542    Derrick Zimmerman        2006      2006        G    6-3   195.0
# 4543    Stephen Zimmerman        2017      2017        C    7-0   240.0
# 4544          Paul Zipser        2017      2018      G-F    6-8   215.0
# 4545           Ante Zizic        2018      2018      F-C   6-11   250.0
# 4546             Jim Zoet        1983      1983        C    7-1   240.0
# 4547            Bill Zopf        1971      1971        G    6-1   170.0
# 4548          Ivica Zubac        2017      2018        C    7-1   265.0
# 4549           Matt Zunic        1949      1949      G-F    6-3   195.0
#
#              birth_date                                            college
# 0         June 24, 1968                                    Duke University
# 1         April 7, 1946                              Iowa State University
# 2        April 16, 1947              University of California, Los Angeles
# 3         March 9, 1969                         Louisiana State University
# 4      November 3, 1974                          San Jose State University
# 5     December 11, 1976                           University of California
# 6           May 6, 1954                                 Indiana University
# 7         July 27, 1932                        Western Kentucky University
# 8      February 9, 1919                     Salem International University
# 9        August 1, 1993                                                NaN
# 10     January 21, 1983                              Pepperdine University
# 11    September 4, 1930                             Long Island University
# 12    November 15, 1962                            Oral Roberts University
# 13     January 11, 1942                                  Hillsdale College
# 14      October 6, 1990                                  Baylor University
# 15        July 19, 1954                             University of Oklahoma
# 16    November 27, 1947                            Northwestern University
# 17         May 15, 1949                            Gardner-Webb University
# 18        June 20, 1984                              University of Arizona
# 19         July 8, 1994              University of California, Los Angeles
# 20     January 19, 1963                                     Boston College
# 21        July 20, 1993                           University of Pittsburgh
# 22        July 22, 1964                                Syracuse University
# 23        July 18, 1997                             University of Kentucky
# 24        June 16, 1946                        Loyola Marymount University
# 25    February 10, 1986                          University of Connecticut
# 26     October 15, 1985              University of California, Los Angeles
# 27     February 9, 1984                          Michigan State University
# 28    December 10, 1959                                  DePaul University
# 29         May 27, 1984                          Missouri State University
# ...                 ...                                                ...
# 4520    August 16, 1995                             University of Kentucky
# 4521      June 27, 1992                               University of Oregon
# 4522  December 31, 1978                                                NaN
# 4523    January 2, 1961                              University of Houston
# 4524       June 1, 1985                  University of Southern California
# 4525     August 4, 1963  Virginia Polytechnic Institute and State Unive...
# 4526       June 1, 1985                           University of Pittsburgh
# 4527      June 21, 1988                    Georgia Institute of Technology
# 4528   February 6, 1976                                Stanford University
# 4529   November 6, 1985                                                NaN
# 4530   December 7, 1925                              St. John's University
# 4531   October 13, 1930                              St. John's University
# 4532    October 5, 1992                                 Indiana University
# 4533       June 8, 1939                                   Miami University
# 4534  November 20, 1947                                   Drake University
# 4535      July 10, 1919                     Washington & Jefferson College
# 4536      April 7, 1987                           University of Notre Dame
# 4537   January 17, 1990                       University of North Carolina
# 4538    October 1, 1957                           Arizona State University
# 4539     April 13, 1964                           University of Washington
# 4540       July 8, 1977                                                NaN
# 4541     August 2, 1973              University of California, Los Angeles
# 4542   December 2, 1981                       Mississippi State University
# 4543  September 9, 1996                    University of Nevada, Las Vegas
# 4544  February 18, 1994                                                NaN
# 4545    January 4, 1997                                                NaN
# 4546  December 20, 1953                              Kent State University
# 4547       June 7, 1948                                Duquesne University
# 4548     March 18, 1997                                                NaN
# 4549  December 19, 1919                       George Washington University
#
# [4550 rows x 8 columns]

# %%
top_5_colleges = ['University of Kentucky',
                  'Duke University',
                  'University of Kansas',
                  'Syracuse University',
                  'University of California, Los Angeles']

# %% [markdown]
# ## Indexing a col based on a list of values

# %%
players["college"] == 'University of Kentucky'
players["college"] == 'Duke University'
print()

# %% [markdown]
# #### Lets take a look at `college` column of `players`

# %%
players['college'].value_counts().head(10)
# Out:
# University of Kentucky                   99
# University of California, Los Angeles    91
# University of North Carolina             87
# University of Kansas                     72
# Duke University                          71
# Indiana University                       60
# University of Notre Dame                 56
# University of Louisville                 55
# University of Arizona                    51
# St. John's University                    51
# Name: college, dtype: int64

# %% [markdown]
# #### We'll use Pandas `.isin()` method to check `college` column against
#
# #### `top_5_colleges` list.

# %%
players['college'].isin(top_5_colleges) # loop through and see if a value in list of values is in the data frame
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19       True
# 20      False
# 21      False
# 22       True
# 23       True
# 24      False
# 25      False
# 26       True
# 27      False
# 28      False
# 29      False
#         ...
# 4520     True
# 4521    False
# 4522    False
# 4523    False
# 4524    False
# 4525    False
# 4526    False
# 4527    False
# 4528    False
# 4529    False
# 4530    False
# 4531    False
# 4532    False
# 4533    False
# 4534    False
# 4535    False
# 4536    False
# 4537    False
# 4538    False
# 4539    False
# 4540    False
# 4541     True
# 4542    False
# 4543    False
# 4544    False
# 4545    False
# 4546    False
# 4547    False
# 4548    False
# 4549    False
# Name: college, Length: 4550, dtype: bool

# %%
in_top_5_colleges = players['college'].isin(top_5_colleges)
print(in_top_5_colleges)
players[in_top_5_colleges]
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19       True
# 20      False
# 21      False
# 22       True
# 23       True
# 24      False
# 25      False
# 26       True
# 27      False
# 28      False
# 29      False
#         ...
# 4520     True
# 4521    False
# 4522    False
# 4523    False
# 4524    False
# 4525    False
# 4526    False
# 4527    False
# 4528    False
# 4529    False
# 4530    False
# 4531    False
# 4532    False
# 4533    False
# 4534    False
# 4535    False
# 4536    False
# 4537    False
# 4538    False
# 4539    False
# 4540    False
# 4541     True
# 4542    False
# 4543    False
# 4544    False
# 4545    False
# 4546    False
# 4547    False
# 4548    False
# 4549    False
# Name: college, Length: 4550, dtype: bool
#                      name  year_start  year_end position height  weight  \
# 0          Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 2     Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 19           Jordan Adams        2015      2016        G    6-5   209.0
# 22         Rafael Addison        1987      1997      F-G    6-7   215.0
# 23            Bam Adebayo        2018      2018      C-F   6-10   243.0
# 26          Arron Afflalo        2008      2018        G    6-5   210.0
# 36            Mark Alarie        1987      1991        F    6-8   217.0
# 39           Cole Aldrich        2011      2018        C   6-11   250.0
# 42        Cliff Alexander        2016      2016        F    6-8   245.0
# 55           Lucius Allen        1970      1979        G    6-2   175.0
# 63         Darrell Allums        1981      1981        F    6-9   220.0
# 81         Derek Anderson        1998      2008        G    6-5   194.0
# 91          Kyle Anderson        2015      2018      F-G    6-9   230.0
# 102          Ike Anigbogu        2018      2018      F-C   6-10   252.0
# 107       Carmelo Anthony        2004      2018        F    6-8   240.0
# 120          Trevor Ariza        2005      2018        F    6-8   215.0
# 129        Tate Armstrong        1978      1979        G    6-3   175.0
# 134        Darrell Arthur        2009      2018        F    6-9   235.0
# 153         William Avery        2000      2002        G    6-2   197.0
# 157      Kelenna Azubuike        2007      2012        G    6-5   220.0
# 171           Toby Bailey        1999      2000        G    6-6   213.0
# 182            Lonzo Ball        2018      2018        G    6-6   190.0
# 185            Gene Banks        1982      1987      F-G    6-7   215.0
# 195          Cliff Barker        1950      1952        G    6-2   185.0
# 199         Don Barksdale        1952      1955      F-C    6-6   200.0
# 204           Matt Barnes        2004      2017        F    6-7   226.0
# 236         Shane Battier        2002      2014        F    6-8   220.0
# 255           Ralph Beard        1950      1951        G   5-10   175.0
# 295       Winston Bennett        1990      1992        F    6-7   210.0
# 313           Henry Bibby        1973      1981        G    6-1   185.0
# ...                   ...         ...       ...      ...    ...     ...
# 4193            John Wall        2011      2018        G    6-4   195.0
# 4196         John Wallace        1997      2004        F    6-8   225.0
# 4204          Rex Walters        1994      2000        G    6-4   190.0
# 4207          Bill Walton        1975      1987      C-F   6-11   210.0
# 4226        Hakim Warrick        2006      2013        F    6-9   219.0
# 4235     Pearl Washington        1987      1989        G    6-2   190.0
# 4236   Richard Washington        1977      1982      F-C   6-11   220.0
# 4240       Darryl Watkins        2008      2012        C   6-11   258.0
# 4241         Bobby Watson        1955      1955        G    6-0   160.0
# 4243          Earl Watson        2002      2014        G    6-1   195.0
# 4249           David Wear        2015      2015        F   6-10   230.0
# 4250          Travis Wear        2015      2015        F   6-10   230.0
# 4281          Walt Wesley        1967      1976        C   6-11   220.0
# 4290    Russell Westbrook        2009      2018        G    6-3   200.0
# 4298      Skippy Whitaker        1955      1955        G    6-1   180.0
# 4306          Jo Jo White        1970      1981        G    6-3   190.0
# 4324         Sidney Wicks        1972      1981      F-C    6-8   225.0
# 4328       Andrew Wiggins        2015      2018      F-G    6-8   199.0
# 4341        Jamaal Wilkes        1975      1986      F-G    6-6   190.0
# 4342         James Wilkes        1981      1983        F    6-7   195.0
# 4382         Jay Williams        2003      2003        G    6-2   195.0
# 4415     Shelden Williams        2007      2012        F    6-9   250.0
# 4430         Bobby Wilson        1968      1968        F    6-8   215.0
# 4445        Trevor Wilson        1991      1996        F    6-7   210.0
# 4455      Justise Winslow        2016      2018        F    6-7   225.0
# 4462          Jeff Withey        2014      2018        C    7-0   231.0
# 4493          Brad Wright        1987      1988        F   6-11   225.0
# 4502        Julian Wright        2008      2011        F    6-8   225.0
# 4520          James Young        2015      2017      G-F    6-6   215.0
# 4541         George Zidek        1996      1998        C    7-0   250.0
#
#               birth_date                                college
# 0          June 24, 1968                        Duke University
# 2         April 16, 1947  University of California, Los Angeles
# 19          July 8, 1994  University of California, Los Angeles
# 22         July 22, 1964                    Syracuse University
# 23         July 18, 1997                 University of Kentucky
# 26      October 15, 1985  University of California, Los Angeles
# 36     December 11, 1963                        Duke University
# 39      October 31, 1988                   University of Kansas
# 42     November 16, 1995                   University of Kansas
# 55    September 26, 1947  University of California, Los Angeles
# 63    September 12, 1958  University of California, Los Angeles
# 81         July 18, 1974                 University of Kentucky
# 91    September 20, 1993  University of California, Los Angeles
# 102     October 22, 1998  University of California, Los Angeles
# 107         May 29, 1984                    Syracuse University
# 120        June 30, 1985  University of California, Los Angeles
# 129      October 5, 1955                        Duke University
# 134       March 25, 1988                   University of Kansas
# 153       August 8, 1979                        Duke University
# 157    December 16, 1983                 University of Kentucky
# 171    November 19, 1975  University of California, Los Angeles
# 182     October 27, 1997  University of California, Los Angeles
# 185         May 15, 1959                        Duke University
# 195     January 15, 1921                 University of Kentucky
# 199       March 31, 1923  University of California, Los Angeles
# 204        March 9, 1980  University of California, Los Angeles
# 236    September 9, 1978                        Duke University
# 255     December 2, 1927                 University of Kentucky
# 295     February 9, 1965                 University of Kentucky
# 313    November 24, 1949  University of California, Los Angeles
# ...                  ...                                    ...
# 4193   September 6, 1990                 University of Kentucky
# 4196    February 9, 1974                    Syracuse University
# 4204      March 12, 1970                   University of Kansas
# 4207    November 5, 1952  University of California, Los Angeles
# 4226        July 8, 1982                    Syracuse University
# 4235     January 6, 1964                    Syracuse University
# 4236       July 15, 1955  University of California, Los Angeles
# 4240    November 8, 1984                    Syracuse University
# 4241      March 22, 1930                 University of Kentucky
# 4243       June 12, 1979  University of California, Los Angeles
# 4249  September 21, 1990  University of California, Los Angeles
# 4250  September 21, 1990  University of California, Los Angeles
# 4281    January 25, 1945                   University of Kansas
# 4290   November 12, 1988  University of California, Los Angeles
# 4298     August 29, 1930                 University of Kentucky
# 4306   November 16, 1946                   University of Kansas
# 4324  September 19, 1949  University of California, Los Angeles
# 4328   February 23, 1995                   University of Kansas
# 4341         May 2, 1953  University of California, Los Angeles
# 4342       April 1, 1958  University of California, Los Angeles
# 4382  September 10, 1981                        Duke University
# 4415    October 21, 1983                        Duke University
# 4430                 NaN                   University of Kansas
# 4445      March 16, 1968  University of California, Los Angeles
# 4455      March 26, 1996                        Duke University
# 4462       March 7, 1990                   University of Kansas
# 4493      March 26, 1962  University of California, Los Angeles
# 4502        May 20, 1987                   University of Kansas
# 4520     August 16, 1995                 University of Kentucky
# 4541      August 2, 1973  University of California, Los Angeles
#
# [382 rows x 8 columns]

# %% [markdown]
# #### Index `players` by `in_top_5_colleges` and grab `name`

# %%
# index entire players df by "in_top_5"
players_in_top_5 = players[in_top_5_colleges]['name']
players_in_top_5.head(20)
# Out:
# 0           Alaa Abdelnaby
# 2      Kareem Abdul-Jabbar
# 19            Jordan Adams
# 22          Rafael Addison
# 23             Bam Adebayo
# 26           Arron Afflalo
# 36             Mark Alarie
# 39            Cole Aldrich
# 42         Cliff Alexander
# 55            Lucius Allen
# 63          Darrell Allums
# 81          Derek Anderson
# 91           Kyle Anderson
# 102           Ike Anigbogu
# 107        Carmelo Anthony
# 120           Trevor Ariza
# 129         Tate Armstrong
# 134         Darrell Arthur
# 153          William Avery
# 157       Kelenna Azubuike
# Name: name, dtype: object

# %% [markdown]
# <br>

# %% [markdown]
# #### We'll use Pandas `.isin()` method to check `players` column in `nba`
# #### against the `players_in_top_5` series we just constructed.

# %%
in_top_colleges = nba['Player'].isin(players_in_top_5)

# %%
in_top_colleges
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
# 5        False
# 6         True
# 7        False
# 8         True
# 9         True
# 10        True
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 24661    False
# 24662    False
# 24663    False
# 24664    False
# 24665    False
# 24666    False
# 24667    False
# 24668    False
# 24669    False
# 24670    False
# 24671    False
# 24672    False
# 24673    False
# 24674    False
# 24675    False
# 24676     True
# 24677     True
# 24678    False
# 24679    False
# 24680    False
# 24681    False
# 24682     True
# 24683    False
# 24684    False
# 24685    False
# 24686    False
# 24687    False
# 24688    False
# 24689    False
# 24690    False
# Name: Player, Length: 24691, dtype: bool

# %% [markdown]
# <br>

# %% [markdown]
# #### We will divide all of the rows of `nba` into `2` dataframes, those players who attended the top colleges, and those who did not.

# %%
top_college = nba[in_top_colleges]
top_college.shape
# Out:
# (2198, 52)

# %%
bottom_college = nba[~in_top_colleges]
bottom_college.shape
# Out:
# (22493, 52)

# %% [markdown]
# <br>

# %% [markdown]
# #### Plot the Players NOT FROM Top 5

# %%
bottom_college['PER'].hist(bins=50) 

# Make it pretty
ax = plt.gca()
ax.set_title("PER for players NOT FROM Top 5 Colleges")
ax.set_xlabel("Player Efficiency Rating")
ax.set_ylabel("# of Players")

# "print" the plot
plt.show()

# %%
bottom_college['PER'].mean()
# Out:
# 12.484063127166582

# %% [markdown]
# #### Plot the Players FROM Top 5

# %%
top_college['PER'].hist(bins=50) 

# Make it pretty
ax = plt.gca()
ax.set_title("PER for players FROM Top 5 Colleges")
ax.set_xlabel("Player Efficiency Rating")
ax.set_ylabel("# of Players")

# "print" the plot
plt.show()

# %%
top_college['PER'].mean()
# Out:
# 12.428801102434512

# %%
top_college = nba_1950['Player'].isin(players
bottom_college = nba_2017[~in_top_colleges]
temp1 = 
temp2 =

# %% [markdown]
# #### What conclusions can we draw about these 2 groups?

# %%
# What could we do better? ...
